# %% [markdown]
# # 라이브러리 설치

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\cleo7\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\cleo7\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\cleo7\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\cleo7\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\cleo7\anaconda3\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\cleo7\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\cleo7\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\cleo7\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\cleo7\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\cleo7\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Selenium 연습

# %% [markdown]
# ## By.Name 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()   # (CDrive Windows 폴더에 내장된 경우)

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr')

# 검색어를 입력할 수 있는 input 요소를 찾습니다.
search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %% [markdown]
# ## By.CSS_SELECTOR 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

title_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 베스트 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr/n/best')

# 상품명을 입력 받아 item_list 변수에 저장합니다.
item_list = driver.find_elements(By.CSS_SELECTOR, 'a.itemname')

for item in item_list:
    title_list.append(item.text)

driver.quit()

# %%
print(title_list)
# Out:
# ['[원할머니]원할머니 명품육개장 600g 10팩', '삼다수 T 제주 삼다수 무라벨 500ml X 40병', '추억의국민학교떡볶이 T국떡 떡볶이 11종 5팩 외 모음', '이쌀이다 촉촉하고 찰진 안동밥상 백진주 10kg', '[삼립]삼립디저트 누네띠네 2.5kgx1개', '[풀무원]풀무원 풀무원 T 노엣지피자 4종 6판 골라담기 (콤비/베이컨/포테이토콘/BBQ)', '[서울우유]서울우유 멸균우유 흰우유 200mlx48개', '다향 훈제오리 13팩 1등급', '[해동찬가]7/24(월) 단하루 20%할인) 한돈대패삼겹살 300gX4팩+한돈대패목살 300gX3팩 /총 7팩(2.1kg)', '[동아오츠카]나랑드사이다 제로 345ml 24캔(뚱캔)', '[할리스]할리스 1L 아메리카노 x4병', '[디스커버리](롯데백화점)디스커버리 공용 마운틴 LT DXSH4112N', '궁중비법 포기김치 10kg', '[코카콜라]코카콜라 190ml x 60CAN', '나비골 국내산 여름별미 열무김치 2kg 2개구매시비빔면증정(주문일자7월24일 기준으로 증정)', '프리미엄 1등급 한우 등심 200g x 2팩 /총 400g /17560원(쿠폰가)/냉장 한우 암소', '(15%쿠폰적용가 8670) 냄새줄인 락스 2100ml x 6개 / 최신제조 / 욕실 및 화장실 살균 소독제', '[동아오츠카]동아오츠카 T 라인바싸 탄산수/탄산음료 500ml 2박스 ( 20입+20입 )', '[목우촌]목우촌주부9단 살코기햄 1kg x 2개', '[코디](15%+클럽12% 쿠폰적용가 25700) 블루 3겹 데코 화장지 27m 30롤 3팩 휴지', '[도루코](최종혜택가 23800원) 페이스6 면도기획세트 2호(면도기+날 총13입+폼) + 6스타일 날2입 증정 / 6중날', '[메가박스](유니버스클럽 전용) 메가박스 일반예매권 2D-주중/주말', '[목우촌]목우촌 주부9단 비엔나소시지 450g x 3개', '무중력 깔창 1+1+1+1 신발 쿠션 충격흡수 완화 군인 등산 구두 푹신한 키높이', '(할인특가/별똥별 신간) 생각의 발견 (도서10권+워크북3권) / 세이펜 미포함', '[동아출판]동아출판 큐브수학 (연산/개념/개념응용/실력/심화 선택구매) - 2권이상무배', '[목우촌]T 목우촌 프라임 한입 돈까스 500g x4봉', '[델포유]델포유 오븐에 구운 십센치 파운드 30개 5가지맛', '제로스킨 스키니매트 (1+1)', '[스카이패션](1+1) 남녀공용 시원한 린넨라이크 쿨 와이드 밴딩팬츠', '[하비비](15%쿠폰) 청개구리 자동 변기 클리너 세정제 6개 (12개월분)', '제로스킨 케이스 시그니처5 (1+1)', '[농협]2023 평창농협 햇 미백찰옥수수 30개', '[더푸룸]섬유유연제 라벤더향 2.5L 4개 (특가행사)', '[엘렌실라](7/24 단하루)(1+1+정품증정) 슈퍼 달팽이크림 50g 1+1 (+프렌치콜라겐 대용량 에멀전 750ml 증정)', '삼다수 T 제주 삼다수 무라벨 2L X 24병', '[맥케인]맥케인 케이준 배터드 감자튀김 2kg+(증정)어니언링 외 모음', '[휠라]휠라 신상 브라/팬티/나시 여름 세일 /인핏 솔리드 여성 브라 (FI4BAD6445F_DID)', '착한낙지 매콤~칼칼 착한낙지 135g x 6팩+비법소스 6팩', '[외할머니밥상]스지 많고 뼈없는 업그레이드 외할머니 도가니탕 500gx4팩 / 2셋트 구매시마다 하나더', '[코카콜라]코카콜라제로 190ml x 60CAN', '[고래사어묵]고래사 고래사어묵 프리미엄어묵세트 (15종 /25개)', '[나이키]나이키 NSW 반팔티셔츠 푸츄라 아이콘 스우시 AR5005 AR5004 택1', '이맛쌀 20kg', '[오롯담]오롯담 나주곰탕 700g 12팩', '제로스킨 케이스 시그니처6 (1+1)', '[어나더디](15%쿠폰가 12670원)(4개세트) 심리스 브라탑 4color 노라인 노와이어 스포츠브라 스판소재', '[오뚜기]오뚜기 맛있는 밥 30입(210gx10)x 3개 / 오뚜기 흰밥', '[동아오츠카]나랑드사이다 350ML 20입 1박스(플레인파인애플그린애플)', '[쁘띠비데]비데물티슈 쁘띠비데 캡형 46매x10팩', '[삼진어묵]삼진어묵 T 삼진어묵 옛날모듬어묵 1Kg x 3개', '[부즈펌](라이카미) 부즈펌 진짜 진짜 재밌는 그림책 골라 담기 - 3권 이상 무료배송', '[아이러브베베]아이러브베베아기물티슈 핑크100매캡형X20팩', '[세포랩]세포랩 바이오제닉 에센스 155ml', '(스마일북스) 뉴 차일드 애플 전55권 세트 : 세이펜별매 창작동화 스테디셀러', '(노티드) 1만원권', '[아르페지오](한정수량 역마진)여름 차렵이불 냉감/모기기피/풍기인견/시어서커/순면/패드', '[천일식품]사누끼 포차 우동 230g10봉 (개별포장) + 소스 10봉 + 후레이크 10개', '[아침농산]2022년 햅쌀 농부의아침 쌀10kg 백미 상등급', '[베베앙(물티슈)]베베앙 아기물티슈 시그니처 대용량 100매 캡형 10팩', '[덴티스테]덴티스테 플러스화이트 160gx3개 + 여행용20g 1개 기본증정 (7/24단하루 치실1개 추가증정) 쿠폰가 23890원', '[살림백서](15%쿠폰적용가 12920) 살림백서 뿌리는 곰팡이제거제 400ml 4개 욕실 베란다', '추추추어탕 500g 5팩 국내산 미꾸라지만 사용', '[제주삼다수][무료배송] 제주 삼다수 그린(무라벨) 2L 24병 (유라벨/무라벨 랜덤발송)', '[서울우유]멸균우유 1000ml x 10입 (1박스)', '강부자 역대최저가/SK단독 부자 뼈없는 갈비탕 800gx10팩', '[롯데제과]롯데제과 초코빼빼로10갑+아몬드빼빼로10갑+누드빼빼로10갑', '미미네 국물떡볶이 9봉 + 눈꽃치즈 국물떡볶이 1봉 (총10봉)', '[풀무원]G풀무원 피자 4종 5판 골라담기 (노엣지/시카고/크로엣지/골드크러스트)', '[삼성전자]새로운 갤럭시폴더블 사전알림 EVENT/ 알림신청 /100원딜(구매시자동응모)', '[피코크]조선호텔 포기김치 8kg(신세계푸드 중복쿠폰 할인)', '[구글플레이]기프트코드 10만원 / 구글 기프트카드', '[목우촌]목우촌 프라임 한입 돈까스 500g x4봉', '[풀무원]G풀무원 토이쿠키 3+1 브레드이발소/킹덤 3개 구매시 1개 더', '[노브랜드]노브랜드 도톰한 물티슈 100매 X 20개입', '[신세계푸드]밀크앤허니 파운드/롤/카스테라 6종 1+1 골라담기 (신세계푸드 중복쿠폰 할인)', '프리미엄 1등급 한우 채끝 200g x 2팩 총 400g /20080원(쿠폰가)/ 냉장 한우 암소', '[벨롭]밸롭 아쿠아슈즈/워터슈즈/래쉬가드/수영복/비치웨어/여성/남성/아동/키즈 모음전', '[대상 웰라이프][최종혜택가22,760원] 마이밀 뉴프로틴 오리지널 24입 +증정', '[맥심]맥심 모카골드 커피믹스 400T', '[대상 웰라이프]뉴케어 구수한맛 200ml x 30팩 /균형영양식 가장 친숙한 맛 누룽지맛 식사대용식 환자영양식', '[바스파]스크럽 사해소금 바디워시/클렌저 각질케어 1000ml 쿠폰가13180 (+행사중)', '[HC해피콜]NEW 컴포트 다이아몬드 후라이팬 2종세트 (28팬+28웍) + 스타벅스 기프티콘 증정', '[아토세이프]최종혜택가 14520원 아토세이프 귀찮아 습기제거제 520ml 24개입/제습제/장마철필수품', '[구글플레이]기프트코드 5만원 / 구글 기프트카드', '[깨끗한나라]깨끗한나라 순수시그니처 화장지 브라운 30m 30롤 2팩', '[BBQ]BBQ 비비큐치킨 공식몰 / 자메이카 통다리 바베큐 x 10팩 / 오늘만 시즈닝 증정', '[샤오미]최종48만 미지아 1S B116 올인원 물걸레 로봇청소기 (관부가세 포함)', '[동원샘물]동원샘물 2L 24병 /생수전문배송', '[스파클]스파클생수 500ml 100병 (도착보장/무라벨생수)', '제로스킨 핸드폰필름 아틀라스 갤럭시', '[올반키친]올반 찰핫도그15봉+크런치핫도그15봉(신세계푸드 중복쿠폰 할인)', '[코카콜라]코카콜라 업소용 500ml 24입', '[헬로]헬로 순수 3겹 30m 30롤 3팩 천연펄프 화장지 초특가행사', '(놀이대전) 캐리비안베이 골드1 골드2 종일권(이용기간 상이)', '[롯데제과]아이스브레이커스 ...

# %% [markdown]
# # selenium 실행하고 상품명, 가격, 별점 정보 저장

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

title_list = list()
price_list = list()
star_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr')

# 검색어를 입력할 수 있는 input 요소를 찾습니다.
search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 결과 페이지가 로드될 때까지 잠시 기다립니다.
driver.implicitly_wait(3)

# 정보를 담은 박스를 선택합니다.
search_results = driver.find_elements(By.CSS_SELECTOR, 'div.box__information')

for result in search_results:
    #만족도가 없을 수도 있기에 try except문을 활용
    try:
        title_element = result.find_element(By.CSS_SELECTOR, 'span.text__item')
        price_element = result.find_element(By.CSS_SELECTOR, 'div.box__price-seller > strong')
        star_element = result.find_element(By.CSS_SELECTOR, 'span.image__awards-points > span')
        title_list.append(title_element.text)
        price_list.append(price_element.text)
        star_list.append(star_element.text)
    except:
        pass
    
# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %% [markdown]
# # 데이터 프레임으로 저장하고 Excel 파일로 저장하기

# %%
import pandas as pd

gmarket_selenium_df = pd.DataFrame([title_list, price_list, star_list]).T

# %%
gmarket_selenium_df.columns = ['상품명', '판매가', '만족도']

# %%
gmarket_selenium_df
# Out:
#                                                상품명     판매가            만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29,900
# 1                       쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기  14,900
# 2               1+1 초특가 무선 선풍기 휴대용 손 선풍기 미니 손풍기 힐템  34,900
# 3               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45,900   만족도 76% 입니다.
# 4   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29,900   만족도 90% 입니다.
# ..                                             ...     ...            ...
# 92             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16,800   만족도 90% 입니다.
# 93            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33,060   만족도 82% 입니다.
# 94                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22,500   만족도 66% 입니다.
# 95             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46,800   만족도 94% 입니다.
# 96                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24,800  만족도 100% 입니다.
#
# [97 rows x 3 columns]

# %%
## 전처리

# %%
def extract_comma(x):
    price = int(x.replace(",", "")) #replace로 쉼표까지 제거하고 int로 변환
    return price

# %%
gmarket_selenium_df['판매가'] = gmarket_selenium_df['판매가'].apply(extract_comma)

# %%
import re

def extract_stars(x):
    ext = re.findall("\d+%", x)
    #데이터가 빈 경우가 있으므로 try, except문 사용
    try:
        stars = int(ext[0].replace('%', "")) #%를 제거한 뒤 int로 변환
    except:
        pass
    return stars if ext else None #데이터가 있을 경우 stars를 반환, 아닐 경우 None을 반환

# %%
gmarket_selenium_df['만족도'] = gmarket_selenium_df['만족도'].apply(extract_stars)

# %%
gmarket_selenium_df = gmarket_selenium_df.dropna().reset_index().iloc[:, 1:]

# %%
gmarket_selenium_df
# Out:
#                                                상품명    판매가    만족도
# 0               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   76.0
# 1   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29900   90.0
# 2    이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터  29900   94.0
# 3                          휴대용 냉각 선풍기 쿨링 핸디팬 다크그레이  27900   88.0
# 4                 LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙  15900   94.0
# ..                                             ...    ...    ...
# 89             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16800   90.0
# 90            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   82.0
# 91                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   66.0
# 92             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   94.0
# 93                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  100.0
#
# [94 rows x 3 columns]

# %%
gmarket_selenium_df.to_excel('gmarket_handfan_stars.xlsx')

# %% [markdown]
# # 과제 (100점)

# %% [markdown]
# #### 본인이 관심 있는 키워드에 대해서 해당 크롤링을 반복해서 수행하시오. 데이터를 수집하여 excel 파일로 저장하시오.

# %%
#1. 필요한 라이브러리 import 하기 (10점)
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
#2. 본인이 관심 있는 키워드에 대해서 크롤링을 수행하고 상품명, 가격, 별점 정보 저장하기 (40점)

title_list = list()
price_list = list()
star_list = list()

driver = webdriver.Chrome()

driver.get('https://www.gmarket.co.kr')

search_box = driver.find_element(By.NAME, 'keyword')


search_box.send_keys('헤드폰')
search_box.send_keys(Keys.RETURN)

driver.implicitly_wait(3)


search_results = driver.find_elements(By.CSS_SELECTOR, 'div.box__information')

for result in search_results:
    try:
        title_element = result.find_element(By.CSS_SELECTOR, 'span.text__item')
        price_element = result.find_element(By.CSS_SELECTOR, 'div.box__price-seller > strong')
        star_element = result.find_element(By.CSS_SELECTOR, 'span.image__awards-points > span')
        title_list.append(title_element.text)
        price_list.append(price_element.text)
        star_list.append(star_element.text)
    except:
        pass
    

driver.quit()

# %%
#3. 적절히 데이터 전처리를 하여 DataFrame 객체로 만들고 Excel 파일로 저장하기 (50점)
#이때, DataFrame의 열은 "상품명, 판매가, 만족도"로 구성되어야 함.

import pandas as pd

df = pd.DataFrame([title_list, price_list, star_list]).T

# %%
df.columns = ['상품명', '판매가', '만족도']

# %%
df
# Out:
#                                                   상품명      판매가            만족도
# 0                   Blank IGH-100 헤드폰 접이식 마이크내장 유선헤드셋   27,900
# 1                       1위스마트헤드셋V1000블루투스무선소니헤드폰 보다특가   60,000
# 2   GM-HC10 C타입 7.1채널 서라운드 게이밍 헤드셋 RGB LED 헤드폰 USB...   29,900
# 3                      BE-STH500 스튜디오 모니터링 보컬 방송용 헤드폰   49,900   만족도 90% 입니다.
# 4                   삼성 헤드셋 SHS-100V/W Premium 화이트 게이밍   30,900   만족도 90% 입니다.
# ..                                                ...      ...            ...
# 90  1+1 최신형 QCY-H2 블루투스 헤드폰 헤드셋 무선 이어폰 헤드폰 1+1 2세트...   37,900   만족도 60% 입니다.
# 91  JZmsq 스마텍 블루투스헤드폰/STBT-H300/풍부한사운드/ 마샬헤드폰 JBL헤...   69,520  만족도 100% 입니다.
# 92                    젠샵젠하이저 HD600 오픈형헤드폰 젠하이저 HD 600  449,000   만족도 96% 입니다.
# 93                      플레오맥스 블루투스헤드셋 PBH-500 유무선 접이식   33,120   만족도 80% 입니다.
# 94        노이즈캔슬링 ANC 무선 블루투스헤드폰 SPH-900Pro BRN (Best)   99,900   만족도 96% 입니다.
#
# [95 rows x 3 columns]

# %%
def extract_comma(x):
    price = int(x.replace(",", "")) #replace로 쉼표까지 제거하고 int로 변환
    return price

df['판매가'] = df['판매가'].apply(extract_comma)

# %%
import re

def extract_stars(x):
    ext = re.findall("\d+%", x)
    #데이터가 빈 경우가 있으므로 try, except문 사용
    try:
        stars = int(ext[0].replace('%', "")) #%를 제거한 뒤 int로 변환
    except:
        pass
    return stars if ext else None #데이터가 있을 경우 stars를 반환, 아닐 경우 None을 반환

# %%
df['만족도'] = df['만족도'].apply(extract_stars)

# %%
df
# Out:
#                                                   상품명     판매가    만족도
# 0                   Blank IGH-100 헤드폰 접이식 마이크내장 유선헤드셋   27900    NaN
# 1                       1위스마트헤드셋V1000블루투스무선소니헤드폰 보다특가   60000    NaN
# 2   GM-HC10 C타입 7.1채널 서라운드 게이밍 헤드셋 RGB LED 헤드폰 USB...   29900    NaN
# 3                      BE-STH500 스튜디오 모니터링 보컬 방송용 헤드폰   49900   90.0
# 4                   삼성 헤드셋 SHS-100V/W Premium 화이트 게이밍   30900   90.0
# ..                                                ...     ...    ...
# 90  1+1 최신형 QCY-H2 블루투스 헤드폰 헤드셋 무선 이어폰 헤드폰 1+1 2세트...   37900   60.0
# 91  JZmsq 스마텍 블루투스헤드폰/STBT-H300/풍부한사운드/ 마샬헤드폰 JBL헤...   69520  100.0
# 92                    젠샵젠하이저 HD600 오픈형헤드폰 젠하이저 HD 600  449000   96.0
# 93                      플레오맥스 블루투스헤드셋 PBH-500 유무선 접이식   33120   80.0
# 94        노이즈캔슬링 ANC 무선 블루투스헤드폰 SPH-900Pro BRN (Best)   99900   96.0
#
# [95 rows x 3 columns]

# %%
df = df.dropna().reset_index().iloc[:, 1:]

# %%
df
# Out:
#                                                   상품명     판매가    만족도
# 0                      BE-STH500 스튜디오 모니터링 보컬 방송용 헤드폰   49900   90.0
# 1                   삼성 헤드셋 SHS-100V/W Premium 화이트 게이밍   30900   90.0
# 2                 무선게이밍 헤드셋 PENTA X11/7.1채널 자동충전/EQ튜닝  149000   94.0
# 3                    소니 MDR-7506 전문가용 모니터링 헤드폰 프로페셔널d  149900  100.0
# 4                무선 게이밍헤드셋/PENTA X5 /7.1채널/PS4/PC/강의용   69900   94.0
# ..                                                ...     ...    ...
# 87  1+1 최신형 QCY-H2 블루투스 헤드폰 헤드셋 무선 이어폰 헤드폰 1+1 2세트...   37900   60.0
# 88  JZmsq 스마텍 블루투스헤드폰/STBT-H300/풍부한사운드/ 마샬헤드폰 JBL헤...   69520  100.0
# 89                    젠샵젠하이저 HD600 오픈형헤드폰 젠하이저 HD 600  449000   96.0
# 90                      플레오맥스 블루투스헤드셋 PBH-500 유무선 접이식   33120   80.0
# 91        노이즈캔슬링 ANC 무선 블루투스헤드폰 SPH-900Pro BRN (Best)   99900   96.0
#
# [92 rows x 3 columns]

# %%
df.to_excel('gmarket_handfan_stars.xlsx')
